# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

if __name__ == "__main__":
    input_shape = (512, 512, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# 2024-06-27 23:02:59.829018: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-27 23:02:59.829149: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-27 23:03:00.088880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512, 512,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 128,  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 32,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      4,096 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 256,  │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 256, 256,  │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 512,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 512, 512,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 512, 512,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 512, 512,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,055,297 (118.47 MB)
#  Trainable params: 31,043,521 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from sklearn.metrics import f1_score

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

import tensorflow as tf

def f1sc(y_true, y_pred):
    # Ensure tensors have the same data type
    y_true = tf.cast(y_true, dtype=y_pred.dtype)

    # Flatten tensors if necessary (for compatibility with some metrics)
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    # Calculate precision and recall
    precision = tf.math.divide_no_nan(tf.reduce_sum(tf.cast(tf.equal(y_true, y_pred), dtype=tf.float32)), tf.reduce_sum(y_pred))
    recall = tf.math.divide_no_nan(tf.reduce_sum(tf.cast(tf.equal(y_true, y_pred), dtype=tf.float32)), tf.reduce_sum(y_true))

      # Calculate F1-score (avoid division by zero)
    f1 = 2 * tf.math.divide_no_nan(precision * recall, precision + recall + 1e-10)

    return f1

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

""" Global parameters """
H = 224
W = 224

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.2):
    images = sorted(glob(os.path.join(path, "images1", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks1", "*.png")))

    if len(images) == 0 or len(masks) == 0:
        raise ValueError("No images or masks found in the specified directory.")

    split_size = int(len(images) * split)
    if split_size == 0:
        split_size = 1  # Ensure at least one sample in validation and test sets

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))  ## (h, w)
    x = x / 255.0        ## (h, w)
    x = x.astype(np.float32)  ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("/kaggle/working/files100")

""" Hyperparameters """
batch_size = 32
lr = 1e-4
num_epochs = 200
model_path = os.path.join("/kaggle/working/files100", "model.keras")
csv_path = os.path.join("/kaggle/working/files100", "log.csv")

""" Dataset """
dataset_path = "/kaggle/input/new-segx2/Data"
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test : {len(test_x)} - {len(test_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

""" Model """
# Assuming build_unet and loss functions are defined elsewhere
model = build_unet((H, W, 3))
model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef,f1sc])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Train: 2394 - 2394
# Valid: 798 - 798
# Test : 798 - 798
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719529617.395198     108 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - dice_coef: 0.2639 - f1sc: 0.0176 - loss: 0.7361
# Epoch 1: val_loss improved from inf to 0.86473, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 579s 5s/step - dice_coef: 0.2650 - f1sc: 0.0180 - loss: 0.7350 - val_dice_coef: 0.1352 - val_f1sc: 0.0000e+00 - val_loss: 0.8647 - learning_rate: 1.0000e-04
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.4805 - f1sc: 0.1632 - loss: 0.5195
# Epoch 2: val_loss did not improve from 0.86473
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.4808 - f1sc: 0.1634 - loss: 0.5192 - val_dice_coef: 0.1106 - val_f1sc: 0.0000e+00 - val_loss: 0.8893 - learning_rate: 1.0000e-04
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.5463 - f1sc: 0.2038 - loss: 0.4537
# Epoch 3: val_loss did not improve from 0.86473
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.5466 - f1sc: 0.2039 - loss: 0.4534 - val_dice_coef: 0.0835 - val_f1sc: 3.1440e-05 - val_loss: 0.9164 - learning_rate: 1.0000e-04
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.5908 - f1sc: 0.2259 - loss: 0.4092
# Epoch 4: val_loss did not improve from 0.86473
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.5911 - f1sc: 0.2260 - loss: 0.4089 - val_dice_coef: 0.1016 - val_f1sc: 0.0092 - val_loss: 0.8983 - learning_rate: 1.0000e-04
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.6373 - f1sc: 0.2589 - loss: 0.3627
# Epoch 5: val_loss improved from 0.86473 to 0.66374, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.6376 - f1sc: 0.2589 - loss: 0.3624 - val_dice_coef: 0.3362 - val_f1sc: 0.0471 - val_loss: 0.6637 - learning_rate: 1.0000e-04
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.6648 - f1sc: 0.2722 - loss: 0.3352
# Epoch 6: val_loss did not improve from 0.66374
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.6651 - f1sc: 0.2722 - loss: 0.3349 - val_dice_coef: 0.2051 - val_f1sc: 0.0541 - val_loss: 0.7947 - learning_rate: 1.0000e-04
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.6933 - f1sc: 0.2927 - loss: 0.3067
# Epoch 7: val_loss improved from 0.66374 to 0.41050, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.6935 - f1sc: 0.2927 - loss: 0.3065 - val_dice_coef: 0.5895 - val_f1sc: 0.1975 - val_loss: 0.4105 - learning_rate: 1.0000e-04
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.7228 - f1sc: 0.3087 - loss: 0.2772
# Epoch 8: val_loss did not improve from 0.41050
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.7230 - f1sc: 0.3088 - loss: 0.2770 - val_dice_coef: 0.5830 - val_f1sc: 0.1316 - val_loss: 0.4170 - learning_rate: 1.0000e-04
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.7529 - f1sc: 0.3333 - loss: 0.2471
# Epoch 9: val_loss improved from 0.41050 to 0.36433, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.7531 - f1sc: 0.3333 - loss: 0.2469 - val_dice_coef: 0.6357 - val_f1sc: 0.1984 - val_loss: 0.3643 - learning_rate: 1.0000e-04
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.7757 - f1sc: 0.3422 - loss: 0.2243
# Epoch 10: val_loss improved from 0.36433 to 0.29571, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - dice_coef: 0.7759 - f1sc: 0.3423 - loss: 0.2241 - val_dice_coef: 0.7043 - val_f1sc: 0.1329 - val_loss: 0.2957 - learning_rate: 1.0000e-04
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.7960 - f1sc: 0.3634 - loss: 0.2040
# Epoch 11: val_loss did not improve from 0.29571
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.7961 - f1sc: 0.3634 - loss: 0.2039 - val_dice_coef: 0.7016 - val_f1sc: 0.2073 - val_loss: 0.2984 - learning_rate: 1.0000e-04
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8053 - f1sc: 0.3841 - loss: 0.1947
# Epoch 12: val_loss improved from 0.29571 to 0.24016, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.8054 - f1sc: 0.3841 - loss: 0.1946 - val_dice_coef: 0.7600 - val_f1sc: 0.3633 - val_loss: 0.2402 - learning_rate: 1.0000e-04
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8175 - f1sc: 0.3942 - loss: 0.1825
# Epoch 13: val_loss did not improve from 0.24016
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - dice_coef: 0.8177 - f1sc: 0.3941 - loss: 0.1823 - val_dice_coef: 0.7497 - val_f1sc: 0.2987 - val_loss: 0.2505 - learning_rate: 1.0000e-04
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8274 - f1sc: 0.4063 - loss: 0.1726
# Epoch 14: val_loss improved from 0.24016 to 0.23298, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.8275 - f1sc: 0.4063 - loss: 0.1725 - val_dice_coef: 0.7672 - val_f1sc: 0.1908 - val_loss: 0.2330 - learning_rate: 1.0000e-04
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8383 - f1sc: 0.4097 - loss: 0.1617
# Epoch 15: val_loss improved from 0.23298 to 0.23239, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.8384 - f1sc: 0.4097 - loss: 0.1616 - val_dice_coef: 0.7677 - val_f1sc: 0.3473 - val_loss: 0.2324 - learning_rate: 1.0000e-04
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8456 - f1sc: 0.4153 - loss: 0.1544
# Epoch 16: val_loss improved from 0.23239 to 0.21273, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.8457 - f1sc: 0.4153 - loss: 0.1543 - val_dice_coef: 0.7874 - val_f1sc: 0.3002 - val_loss: 0.2127 - learning_rate: 1.0000e-04
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8596 - f1sc: 0.4256 - loss: 0.1404
# Epoch 17: val_loss improved from 0.21273 to 0.19208, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - dice_coef: 0.8597 - f1sc: 0.4256 - loss: 0.1403 - val_dice_coef: 0.8081 - val_f1sc: 0.3758 - val_loss: 0.1921 - learning_rate: 1.0000e-04
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8686 - f1sc: 0.4313 - loss: 0.1314
# Epoch 18: val_loss did not improve from 0.19208
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.8687 - f1sc: 0.4311 - loss: 0.1313 - val_dice_coef: 0.7994 - val_f1sc: 0.1242 - val_loss: 0.2008 - learning_rate: 1.0000e-04
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8766 - f1sc: 0.4359 - loss: 0.1234
# Epoch 19: val_loss did not improve from 0.19208
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.8767 - f1sc: 0.4358 - loss: 0.1233 - val_dice_coef: 0.7941 - val_f1sc: 0.1720 - val_loss: 0.2060 - learning_rate: 1.0000e-04
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8848 - f1sc: 0.4373 - loss: 0.1152
# Epoch 20: val_loss did not improve from 0.19208
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.8849 - f1sc: 0.4372 - loss: 0.1151 - val_dice_coef: 0.7942 - val_f1sc: 0.1515 - val_loss: 0.2059 - learning_rate: 1.0000e-04
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8911 - f1sc: 0.4451 - loss: 0.1089
# Epoch 21: val_loss improved from 0.19208 to 0.17577, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.8911 - f1sc: 0.4449 - loss: 0.1089 - val_dice_coef: 0.8243 - val_f1sc: 0.2834 - val_loss: 0.1758 - learning_rate: 1.0000e-04
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.8938 - f1sc: 0.4388 - loss: 0.1062
# Epoch 22: val_loss did not improve from 0.17577
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.8939 - f1sc: 0.4388 - loss: 0.1061 - val_dice_coef: 0.8193 - val_f1sc: 0.2339 - val_loss: 0.1807 - learning_rate: 1.0000e-04
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9011 - f1sc: 0.4614 - loss: 0.0989
# Epoch 23: val_loss did not improve from 0.17577
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.9011 - f1sc: 0.4612 - loss: 0.0989 - val_dice_coef: 0.8065 - val_f1sc: 0.3759 - val_loss: 0.1936 - learning_rate: 1.0000e-04
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9028 - f1sc: 0.4472 - loss: 0.0972
# Epoch 24: val_loss improved from 0.17577 to 0.16748, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - dice_coef: 0.9029 - f1sc: 0.4472 - loss: 0.0971 - val_dice_coef: 0.8326 - val_f1sc: 0.3171 - val_loss: 0.1675 - learning_rate: 1.0000e-04
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9132 - f1sc: 0.4654 - loss: 0.0868
# Epoch 25: val_loss did not improve from 0.16748
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9132 - f1sc: 0.4654 - loss: 0.0868 - val_dice_coef: 0.8178 - val_f1sc: 0.2244 - val_loss: 0.1824 - learning_rate: 1.0000e-04
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9183 - f1sc: 0.4587 - loss: 0.0817
# Epoch 26: val_loss improved from 0.16748 to 0.16722, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9183 - f1sc: 0.4588 - loss: 0.0817 - val_dice_coef: 0.8329 - val_f1sc: 0.2628 - val_loss: 0.1672 - learning_rate: 1.0000e-04
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9228 - f1sc: 0.4666 - loss: 0.0772
# Epoch 27: val_loss did not improve from 0.16722
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9228 - f1sc: 0.4665 - loss: 0.0772 - val_dice_coef: 0.8203 - val_f1sc: 0.1601 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9259 - f1sc: 0.4894 - loss: 0.0741
# Epoch 28: val_loss did not improve from 0.16722
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.9259 - f1sc: 0.4893 - loss: 0.0741 - val_dice_coef: 0.8298 - val_f1sc: 0.2839 - val_loss: 0.1703 - learning_rate: 1.0000e-04
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9271 - f1sc: 0.4896 - loss: 0.0729
# Epoch 29: val_loss did not improve from 0.16722
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9272 - f1sc: 0.4896 - loss: 0.0728 - val_dice_coef: 0.8228 - val_f1sc: 0.2686 - val_loss: 0.1774 - learning_rate: 1.0000e-04
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9310 - f1sc: 0.5088 - loss: 0.0690
# Epoch 30: val_loss did not improve from 0.16722
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9311 - f1sc: 0.5086 - loss: 0.0689 - val_dice_coef: 0.7780 - val_f1sc: 0.1288 - val_loss: 0.2221 - learning_rate: 1.0000e-04
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9245 - f1sc: 0.4970 - loss: 0.0755
# Epoch 31: val_loss did not improve from 0.16722
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9246 - f1sc: 0.4969 - loss: 0.0754 - val_dice_coef: 0.8207 - val_f1sc: 0.3705 - val_loss: 0.1795 - learning_rate: 1.0000e-04
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9269 - f1sc: 0.4995 - loss: 0.0731
# Epoch 32: val_loss improved from 0.16722 to 0.16057, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9270 - f1sc: 0.4995 - loss: 0.0730 - val_dice_coef: 0.8395 - val_f1sc: 0.3203 - val_loss: 0.1606 - learning_rate: 1.0000e-05
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9371 - f1sc: 0.5015 - loss: 0.0629
# Epoch 33: val_loss improved from 0.16057 to 0.15521, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - dice_coef: 0.9371 - f1sc: 0.5015 - loss: 0.0629 - val_dice_coef: 0.8449 - val_f1sc: 0.3218 - val_loss: 0.1552 - learning_rate: 1.0000e-05
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9399 - f1sc: 0.5022 - loss: 0.0601
# Epoch 34: val_loss improved from 0.15521 to 0.15507, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9400 - f1sc: 0.5022 - loss: 0.0600 - val_dice_coef: 0.8451 - val_f1sc: 0.3084 - val_loss: 0.1551 - learning_rate: 1.0000e-05
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9418 - f1sc: 0.5086 - loss: 0.0582
# Epoch 35: val_loss improved from 0.15507 to 0.15379, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9419 - f1sc: 0.5086 - loss: 0.0581 - val_dice_coef: 0.8464 - val_f1sc: 0.3038 - val_loss: 0.1538 - learning_rate: 1.0000e-05
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9437 - f1sc: 0.5088 - loss: 0.0563
# Epoch 36: val_loss improved from 0.15379 to 0.15024, saving model to /kaggle/working/files100/model.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9437 - f1sc: 0.5087 - loss: 0.0563 - val_dice_coef: 0.8499 - val_f1sc: 0.3326 - val_loss: 0.1502 - learning_rate: 1.0000e-05
# Epoch 37/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9452 - f1sc: 0.5043 - loss: 0.0548
# Epoch 37: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9452 - f1sc: 0.5042 - loss: 0.0548 - val_dice_coef: 0.8486 - val_f1sc: 0.3215 - val_loss: 0.1516 - learning_rate: 1.0000e-05
# Epoch 38/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9464 - f1sc: 0.5068 - loss: 0.0536
# Epoch 38: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9465 - f1sc: 0.5068 - loss: 0.0535 - val_dice_coef: 0.8486 - val_f1sc: 0.3282 - val_loss: 0.1515 - learning_rate: 1.0000e-05
# Epoch 39/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9476 - f1sc: 0.5102 - loss: 0.0524
# Epoch 39: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9477 - f1sc: 0.5102 - loss: 0.0523 - val_dice_coef: 0.8491 - val_f1sc: 0.3351 - val_loss: 0.1510 - learning_rate: 1.0000e-05
# Epoch 40/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9487 - f1sc: 0.5122 - loss: 0.0513
# Epoch 40: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9487 - f1sc: 0.5121 - loss: 0.0513 - val_dice_coef: 0.8488 - val_f1sc: 0.3300 - val_loss: 0.1514 - learning_rate: 1.0000e-05
# Epoch 41/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9499 - f1sc: 0.5132 - loss: 0.0501
# Epoch 41: val_loss did not improve from 0.15024
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9499 - f1sc: 0.5132 - loss: 0.0501 - val_dice_coef: 0.8480 - val_f1sc: 0.3256 - val_loss: 0.1521 - learning_rate: 1.0000e-05
# Epoch 42/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9509 - f1sc: 0.5129 - loss: 0.0491
# Epoch 42: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9509 - f1sc: 0.5129 - loss: 0.0491 - val_dice_coef: 0.8490 - val_f1sc: 0.3440 - val_loss: 0.1511 - learning_rate: 1.0000e-06
# Epoch 43/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9511 - f1sc: 0.5132 - loss: 0.0489
# Epoch 43: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9512 - f1sc: 0.5132 - loss: 0.0488 - val_dice_coef: 0.8494 - val_f1sc: 0.3536 - val_loss: 0.1507 - learning_rate: 1.0000e-06
# Epoch 44/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9513 - f1sc: 0.5139 - loss: 0.0487
# Epoch 44: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - dice_coef: 0.9513 - f1sc: 0.5139 - loss: 0.0487 - val_dice_coef: 0.8497 - val_f1sc: 0.3593 - val_loss: 0.1505 - learning_rate: 1.0000e-06
# Epoch 45/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9515 - f1sc: 0.5145 - loss: 0.0485
# Epoch 45: val_loss did not improve from 0.15024
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.
200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9525 - f1sc: 0.5158 - loss: 0.0475
# Epoch 79: val_loss did not improve from 0.15022
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - dice_coef: 0.9526 - f1sc: 0.5158 - loss: 0.0474 - val_dice_coef: 0.8499 - val_f1sc: 0.3731 - val_loss: 0.1502 - learning_rate: 1.0000e-07
# Epoch 80/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9526 - f1sc: 0.5158 - loss: 0.0474
# Epoch 80: val_loss did not improve from 0.15022
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9526 - f1sc: 0.5158 - loss: 0.0474 - val_dice_coef: 0.8499 - val_f1sc: 0.3731 - val_loss: 0.1502 - learning_rate: 1.0000e-07
# Epoch 81/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - dice_coef: 0.9526 - f1sc: 0.5159 - loss: 0.0474
# Epoch 81: val_loss did not improve from 0.15022
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - dice_coef: 0.9526 - f1sc: 0.5158 - loss: 0.0474 - val_dice_coef: 0.8499 - val_f1sc: 0.3732 - val_loss: 0.1502 - learning_rate: 1.0000e-07

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
""" Global parameters """
H = 224
W = 224

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("/kaggle/working/results")

""" Load the model """
with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss,"f1sc":f1sc}):
    model = tf.keras.models.load_model("/kaggle/working/files100/model.keras")

""" Dataset """
dataset_path = "/kaggle/input/new-segx2/Data"
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_y)):
    """ Extracting the name """
    name = x.split("/")[-1]

    """ Reading the image """
    image = cv2.imread(x, cv2.IMREAD_COLOR) ## [H, w, 3]
    image = cv2.resize(image, (W, H))       ## [H, w, 3]
    x = image/255.0                         ## [H, w, 3]
    x = np.expand_dims(x, axis=0)           ## [1, H, w, 3]

    """ Reading the mask """
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (W, H))

    """ Prediction """
    y_pred = model.predict(x, verbose=0)[0]
    y_pred = np.squeeze(y_pred, axis=-1)
    y_pred = y_pred >= 0.5
    y_pred = y_pred.astype(np.int32)

    """ Saving the prediction """
    save_image_path = "/kaggle/working/results/"+name
    save_results(image, mask, y_pred, save_image_path)

    """ Flatten the array """
    mask = mask/255.0
    mask = (mask > 0.5).astype(np.int32).flatten()
    y_pred = y_pred.flatten()

    """ Calculating the metrics values """
    f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    SCORE.append([name, f1_value, jac_value, recall_value, precision_value])

""" Metrics values """
# print(SCORE)
score = [s[1:]for s in SCORE]
#print(score)
score = np.mean(score, axis=0)
print(f"F1: {score[0]:0.5f}")
print(f"Jaccard: {score[1]:0.5f}")
print(f"Recall: {score[2]:0.5f}")
print(f"Precision: {score[3]:0.5f}")

df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("/kaggle/working/files100/score.csv")
# Out:
# 100%|██████████| 798/798 [03:11<00:00,  4.17it/s]
# F1: 0.76444
# Jaccard: 0.70198
# Recall: 0.76208
# Precision: 0.81218
